# %% [markdown]
# <a href="https://colab.research.google.com/github/vensilver/hexo/blob/master/ftxtrade.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install ciso8601
# %pip install ccxt
# %pip install ccxt simplejson

# %%
import ftx
client = ftx.FtxClient()

# %%
import ccxt

def read_setting():
        with open('/content/drive/MyDrive/botsetting/setting.json') as json_file:
            return json.load(json_file)
             
config = read_setting()
LOGFILE= config["LOGFILE"]

exchange  = ccxt.ftx({
    'verbose': False,
    'apiKey': config["apiKey"],
    'secret': config["secret"],
    'enableRateLimit': True,
    'headers': {
        'FTX-SUBACCOUNT': config["sub_account"],
  },

        

})

balance = exchange.fetch_balance()

print(balance['total']['USD'])
# Out:
# 3.70823052

# %%
# coding=utf-8
# %pip install ccxt
# %pip install ccxt simplejson

import ccxt
import datetime
import time
import os
import sys
import simplejson as json
# import random
# import threading

COLOR_RESET = "\033[0;0m"
COLOR_GREEN = "\033[0;32m"
COLOR_RED = "\033[1;31m"
COLOR_BLUE = "\033[1;34m"
COLOR_WHITE = "\033[1;37m"
LOGFILE=""

class Oreder_Info:
    def __init__(self):
        self.done=False
        self.side=None
        self.id=0

class Grid_trader:
    order_list=[]

    def __init__(self,exchange,symbol,grid_level=0,lower_price=0.0,upper_price=0.0,amount=0):
        self.symbol = symbol
        self.exchange=exchange
        self.order_min_inteval= self.exchange.markets[self.symbol]["info"]["priceIncrement"]
        self.grid_level=grid_level
        self.upper_price=upper_price
        self.lower_price=lower_price
        self.amount=amount
        self.inteval_profit=(self.upper_price-self.lower_price) / self.grid_level
        pass

    def place_order_init(self):
        #start cal level and place grid oreder
        for i in range(self.grid_level + 1): #  n+1 lines make n grid
            price = self.lower_price + i * self.inteval_profit
            bid_price, ask_price = self.send_request("get_bid_ask_price")
            order = Oreder_Info()
            if  price < ask_price : 
                order.id = self.send_request("place_order","buy",price)
                log("place buy order id = " + str(order.id) + " in "+ str(price))
            else:
                order.id = self.send_request("place_order","sell",price)
                log("place sell order id = " + str(order.id) + " in "+ str(price))
            self.order_list.append(order)
    
    def loop_job(self):
        for order in self.order_list:
            order_info = self.send_request("get_order",order.id)
            side = order_info["side"]
            if order_info["status"] == "closed":
                new_order_price = 0.0
                old_order_id = order_info["id"]
                bid_price, ask_price = self.send_request("get_bid_ask_price")
                msg = side + " order id : " + str(old_order_id)+" : " + str(order_info["price"]) + " completed , put "
                if side == "buy" :
                    new_order_price = float(order_info["price"]) + self.inteval_profit 
                    order.id = self.send_request("place_order","sell",new_order_price)
                    msg = msg + "sell"
                    log(msg)
                else:
                    new_order_price = float(order_info["price"]) - self.inteval_profit
                    order.id = self.send_request("place_order","buy",new_order_price)
                    msg = msg + "buy"
                msg = msg + " order id : " + str(order.id) + " : " + str(new_order_price)
                log(msg)

    def send_request(self,task,input1=None,input2=None):
        tries = 3
        for i in range(tries):
            try:
                if task == "get_bid_ask_price":
                    ticker =self.exchange.fetch_ticker(self.symbol)
                    return ticker["bid"],  ticker["ask"]

                elif task == "get_order":
                    return self.exchange.fetchOrder(input1)["info"]

                elif task == "place_order":
                    #send_request(self,task,input1=side,input2=price)
                    side = input1
                    price = input2
                    orderid=0
                    if side =="buy":
                        orderid = self.exchange.create_limit_buy_order(self.symbol,self.amount,price )["info"]["id"]
                    else:
                        orderid = self.exchange.create_limit_sell_order(self.symbol,self.amount,price )["info"]["id"]
                    return orderid

                else:
                    return None
            except ccxt.NetworkError as e:
                if i < tries - 1: # i is zero indexed
                    log("NetworkError , try last "+str(i) +"chances" + str(e))
                    time.sleep(0.5)
                    continue
                else:
                    log(str(e))
                    raise
            except ccxt.ExchangeError as e:
                if i < tries - 1: # i is zero indexed
                    log(str(e))
                    time.sleep(0.5)
                    continue
                else:
                    log(str(e))
                    raise
            break

def log(msg):
    timestamp = datetime.datetime.now().strftime("%b %d %Y %H:%M:%S ")
    s = "[%s] %s:%s %s" % (timestamp, COLOR_WHITE, COLOR_RESET, msg)
    print(s)
    try:
        f = open(LOGFILE, "a")
        f.write(s + "\n")
        f.close()
    except:
        pass

def read_setting():
        with open('/content/drive/MyDrive/botsetting/setting.json') as json_file:
            return json.load(json_file)
             
config = read_setting()
LOGFILE= config["LOGFILE"]

exchange  = ccxt.ftx({
    'verbose': False,
    'apiKey': config["apiKey"],
    'secret': config["secret"],
    'enableRateLimit': True,
    'headers': {
        'FTX-SUBACCOUNT': config["sub_account"],
    },
})

exchange_markets = exchange.load_markets()

main_job = Grid_trader(exchange,config["symbol"],config["grid_level"],config["lower_price"],config["upper_price"],config["amount"])
main_job.place_order_init()
while True:
    print("Loop in :",datetime.datetime.now())
    main_job.loop_job()
    time.sleep(1)
# Out:
# Requirement already satisfied: ccxt in /usr/local/lib/python3.7/dist-packages (1.54.54)
# Requirement already satisfied: aiodns<2.1,>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from ccxt) (2.0.0)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.7/dist-packages (from ccxt) (2.23.0)
# Requirement already satisfied: cryptography>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from ccxt) (3.4.7)
# Requirement already satisfied: setuptools>=38.5.1 in /usr/local/lib/python3.7/dist-packages (from ccxt) (57.2.0)
# Requirement already satisfied: certifi>=2018.1.18 in /usr/local/lib/python3.7/dist-packages (from ccxt) (2021.5.30)
# Requirement already satisfied: yarl==1.6.3 in /usr/local/lib/python3.7/dist-packages (from ccxt) (1.6.3)
# Requirement already satisfied: aiohttp<3.8,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from ccxt) (3.7.4.post0)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.7/dist-packages (from yarl==1.6.3->ccxt) (2.10)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from yarl==1.6.3->ccxt) (3.7.4.3)
# Requirement already satisfied: multidict>=4.0 in /usr/local/lib/python3.7/dist-packages (from yarl==1.6.3->ccxt) (5.1.0)
# Requirement already satisfied: pycares>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from aiodns<2.1,>=1.1.1->ccxt) (4.0.0)
# Requirement already satisfied: async-timeout<4.0,>=3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp<3.8,>=3.7.4->ccxt) (3.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp<3.8,>=3.7.4->ccxt) (21.2.0)
# Requirement already satisfied: chardet<5.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp<3.8,>=3.7.4->ccxt) (3.0.4)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography>=2.6.1->ccxt) (1.14.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography>=2.6.1->ccxt) (2.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->ccxt) (1.24.3)
# Requirement already satisfied: ccxt in /usr/local/lib/python3.7/dist-packages (1.54.54)
# Requirement already satisfied: simplejson in /usr/local/lib/python3.7/dist-packages (3.17.3)
# Requirement already satisfied: aiohttp<3.8,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from ccxt) (3.7.4.post0)
# Requirement already satisfied: setuptools>=38.5.1 in /usr/local/lib/python3.7/dist-packages (from ccxt) (57.2.0)
# Requirement already satisfied: certifi>=2018.1.18 in /usr/local/lib/python3.7/dist-packages (from ccxt) (2021.5.30)
# Requirement already satisfied: cryptography>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from ccxt) (3.4.7)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.7/dist-packages (from ccxt) (2.23.0)
# Requirement already satisfied: yarl==1.6.3 in /usr/local/lib/python3.7/dist-packages (from ccxt) (1.6.3)
# Requirement already satisfied: aiodns<2.1,>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from ccxt) (2.0.0)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.7/dist-packages (from yarl==1.6.3->ccxt) (2.10)
# Requirement already satisfied: multidict>=4.0 in /usr/local/lib/python3.7/dist-packages (from yarl==1.6.3->ccxt) (5.1.0)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from yarl==1.6.3->ccxt) (3.7.4.3)
# Requirement already satisfied: pycares>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from aiodns<2.1,>=1.1.1->ccxt) (4.0.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp<3.8,>=3.7.4->ccxt) (21.2.0)
# Requirement already satisfied: async-timeout<4.0,>=3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp<3.8,>=3.7.4->ccxt) (3.0.1)
# Requirement already satisfied: chardet<5.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp<3.8,>=3.7.4->ccxt) (3.0.4)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography>=2.6.1->ccxt) (1.14.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography>=2.6.1->ccxt) (2.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->ccxt) (1.24.3)
# [Aug 06 2021 15:14:56 ] : place buy order id = 68889037722 in 30000.0
# [Aug 06 2021 15:14:56 ] : ftx {"success":false,"error":"Not enough balances"}
# [Aug 06 2021 15:14:58 ] : ftx {"success":false,"error":"Not enough balances"}
# [Aug 06 2021 15:14:59 ] : ftx {"success":false,"error":"Not enough balances"}
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ccxt/base/exchange.py in fetch(self, url, method, headers, body)
#     596             self.logger.debug("%s %s, Response: %s %s %s", method, url, http_status_code, headers, http_response)
# --> 597             response.raise_for_status()
#     598
#
# /usr/local/lib/python3.7/dist-packages/requests/models.py in raise_for_status(self)
#     940         if http_error_msg:
# --> 941             raise HTTPError(http_error_msg, response=self)
#     942
#
# HTTPError: 400 Client Error: BAD REQUEST for url: https://ftx.com/api/orders
#
# During handling of the above exception, another exception occurred:
#
# InsufficientFunds                         Traceback (most recent call last)
# <ipython-input-13-c46f1b123f1d> in <module>()
#     147
#     148 main_job = Grid_trader(exchange,config["symbol"],config["grid_level"],config["lower_price"],config["upper_price"],config["amount"])
# --> 149 main_job.place_order_init()
#     150 while True:
#     151     print("Loop in :",datetime.datetime.now())
#
# <ipython-input-13-c46f1b123f1d> in place_order_init(self)
#      46             order = Oreder_Info()
#      47             if  price < ask_price :
# ---> 48                 order.id = self.send_request("place_order","buy",price)
#      49                 log("place buy order id = " + str(order.id) + " in "+ str(price))
#      50             else:
#
# <ipython-input-13-c46f1b123f1d> in send_request(self, task, input1, input2)
#      91                     orderid=0
#      92                     if side =="buy":
# ---> 93                         orderid = self.exchange.create_limit_buy_order(self.symbol,self.amount,price )["info"]["id"]
#      94                     else:
#      95                         orderid = self.exchange.create_limit_sell_order(self.symbol,self.amount,price )["info"]["id"]
#
# /usr/local/lib/python3.7/dist-packages/ccxt/base/exchange.py in create_limit_buy_order(self, symbol, amount, price, params)
#    1983
#    1984     def create_limit_buy_order(self, symbol, amount, price, params={}) -> dict:
# -> 1985         return self.create_order(symbol, 'limit', 'buy', amount, price, params)
#    1986
#    1987     def create_limit_sell_order(self, symbol, amount, price, params={}) -> dict:
#
# /usr/local/lib/python3.7/dist-packages/ccxt/ftx.py in create_order(self, symbol, type, side, amount, price, params)
#    1187         else:
#    1188             raise InvalidOrder(self.id + ' createOrder() does not support order type ' + type + ', only limit, market, stop, trailingStop, or takeProfit orders are supported')
# -> 1189         response = getattr(self, method)(self.extend(request, params))
#    1190         #
#    1191         # orders
#
# /usr/local/lib/python3.7/dist-packages/ccxt/base/exchange.py in inner(_self, params)
#     461                             if params is not None:
#     462                                 inner_kwargs['params'] = params
# --> 463                             return entry(_self, **inner_kwargs)
#     464                         return inner
#     465                     to_bind = partialer()
#
# /usr/local/lib/python3.7/dist-packages/ccxt/base/exchange.py in request(self, path, api, method, params, headers, body)
#     488     def request(self, path, api='public', method='GET', params={}, headers=None, body=None):
#     489         """Exchange.request is the entry point for all generated methods"""
# --> 490         return self.fetch2(path, api, method, params, headers, body)
#     491
#     492     @staticmethod
#
# /usr/local/lib/python3.7/dist-packages/ccxt/base/exchange.py in fetch2(self, path, api, method, params, headers, body)
#     484         self.lastRestRequestTimestamp = self.milliseconds()
#     485         request = self.sign(path, api, method, params, headers, body)
# --> 486         return self.fetch(request['url'], request['method'], request['headers'], request['body'])
#     487
#     488     def request(self, path, api='public', method='GET', params={}, headers=None, body=None):
#
# /usr/local/lib/python3.7/dist-packages/ccxt/base/exchange.py in fetch(self, url, method, headers, body)
#     611         except HTTPError as e:
#     612             details = ' '.join([self.id, method, url])
# --> 613             self.handle_errors(http_status_code, http_status_text, url, method, headers, http_response, json_response, request_headers, request_body)
#     614             self.handle_http_status_code(http_status_code, http_status_text, url, method, http_response)
#     615             raise ExchangeError(details) from e
#
# /usr/local/lib/python3.7/dist-packages/ccxt/ftx.py in handle_errors(self, code, reason, url, method, headers, body, response, requestHeaders, requestBody)
#    1888             feedback = self.id + ' ' + body
#    1889             error = self.safe_string(response, 'error')
# -> 1890             self.throw_exactly_matched_exception(self.exceptions['exact'], error, feedback)
#    1891             self.throw_broadly_matched_exception(self.exceptions['broad'], error, feedback)
#    1892             raise ExchangeError(feedback)  # unknown message
#
# /usr/local/lib/python3.7/dist-packages/ccxt/base/exchange.py in throw_exactly_matched_exception(self, exact, string, message)
#     502     def throw_exactly_matched_exception(self, exact, string, message):
#     503         if string in exact:
# --> 504             raise exact[string](message)
#     505
#     506     def throw_broadly_matched_exception(self, broad, string, message):
#
# InsufficientFunds: ftx {"success":false,"error":"Not enough balances"}

# %%
import ftx

c =  ftx(
    api_key='hvRdfmujWfmr6hSXcac9JzIg-LngTdzN1UQp5F2F',
    api_secret='v2RkFwuiOdsn3Gy3a4d9W6HHhMYhdMSoElQCUHDA',
)

balance = c.get_balances()
print(balance)
btc_total = next((b['total'] for b in balance if b['coin'] == 'BTC'))
print(btc_total)
